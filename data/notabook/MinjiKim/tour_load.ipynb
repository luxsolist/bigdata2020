# %%
import pandas as pd
df = pd.read_csv('C:/rsource2/tour_data.csv')

# %% [markdown]
# ## 중분류
# - 중분류로 group화 한 결과 총 21542의 데이터중
#     - B0201(숙박시설) : 3713
#     - B0102(교통수단) : 2
#     - A0401(쇼핑) : 989
#     - A0502(음식점) 5528
#     - 총 10232
#
# - 위 네가지를 제외한 데이터 수 : 11310

# %%
df.groupby('cat2').size()
# Out:
# cat2
# A0101    2593
# A0102     122
# A0201    3996
# A0202     876
# A0203    1286
# A0204     253
# A0205     267
# A0206    1914
# A0401     989
# A0502    5528
# B0102       2
# B0201    3713
# dtype: int64

# %% [markdown]
# ## areacode
# 1. 서울 : 2548
# 2. 인천 : 655
# 3. 대전 : 366
# 4. 대구 : 440
# 5. 광주 : 324
# 6. 부산 : 702
# 7. 울산 :544
# 8. 세종특별자치시 : 49
#
#
# 31. 경기도 : 2277
# 32. 강원도 : 2585
# 33. 충청북도 : 969
# 34. 충청남도 : 1196
# 35. 경상북도 : 1912
# 36. 경상남도 : 2360
# 37. 전라북도 : 1821
# 38. 전라남도 : 1929
# 39. 제주도 : 862

# %%
df.groupby('areacode').size()
# Out:
# areacode
# 1.0     2548
# 2.0      655
# 3.0      366
# 4.0      440
# 5.0      324
# 6.0      702
# 7.0      544
# 8.0       49
# 31.0    2277
# 32.0    2585
# 33.0     969
# 34.0    1196
# 35.0    1912
# 36.0    2360
# 37.0    1821
# 38.0    1929
# 39.0     862
# dtype: int64

# %% [markdown]
# ### 숙박, 교통, 쇼핑, 음식점 제외하고 지역별 분류

# %%
df1 = df.copy()

# %%
list = ['B0201','B0102','A0401','A0502']

# %%
c = df1[~df1['cat2'].isin(list)]

# %%
c.groupby('areacode').size()
# Out:
# areacode
# 1.0      979
# 2.0      317
# 3.0      127
# 4.0      259
# 5.0      168
# 6.0      288
# 7.0      149
# 8.0       37
# 31.0    1267
# 32.0    1453
# 33.0     704
# 34.0     737
# 35.0    1226
# 36.0    1076
# 37.0    1002
# 38.0    1122
# 39.0     397
# dtype: int64

# %% [markdown]
# ## 지역별, 중분류를 기준으로 카운트
# - 카테고리별 갯수가 10개가 되지않는 것들도 있음

# %%
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

# %%
b = pd.DataFrame(df.groupby(by=['areacode','cat2']).size())

# %%
b
# Out:
#                   0
# areacode cat2
# 1.0      A0101   47
#          A0102    4
#          A0201  199
#          A0202  118
#          A0203   95
#          A0204   36
#          A0205   55
#          A0206  425
#          A0401  253
#          A0502  931
#          B0201  385
# 2.0      A0101   82
#          A0102    4
#          A0201   83
#          A0202   27
#          A0203   27
#          A0204   10
#          A0205   10
#          A0206   74
#          A0401   31
#          A0502  180
#          B0201  127
# 3.0      A0101   15
#          A0201   40
#          A0202   13
#          A0203   10
#          A0204    9
#          A0206   40
#          A0401   10
#          A0502  211
#          B0201   18
# 4.0      A0101   16
#          A0102    2
#          A0201  108
#          A0202   23
#          A0203   36
#          A0204    9
#          A0205    4
#          A0206   61
#          A0401   19
#          A0502  109
#          B0201   53
# 5.0      A0101   25
# ...

# %%
len(b)
# Out:
# 185

# %% [markdown]
# ### 숙박, 교통, 쇼핑, 음식점 제외하고 지역별,중분류로 카운트

# %%
d = pd.DataFrame(c.groupby(by=['areacode','cat2']).size())

# %%
d
# Out:
#                   0
# areacode cat2
# 1.0      A0101   47
#          A0102    4
#          A0201  199
#          A0202  118
#          A0203   95
#          A0204   36
#          A0205   55
#          A0206  425
# 2.0      A0101   82
#          A0102    4
#          A0201   83
#          A0202   27
#          A0203   27
#          A0204   10
#          A0205   10
#          A0206   74
# 3.0      A0101   15
#          A0201   40
#          A0202   13
#          A0203   10
#          A0204    9
#          A0206   40
# 4.0      A0101   16
#          A0102    2
#          A0201  108
#          A0202   23
#          A0203   36
#          A0204    9
#          A0205    4
#          A0206   61
# 5.0      A0101   25
#          A0102    3
#          A0201   72
#          A0202   17
#          A0203   12
#          A0204    4
#          A0205    4
#          A0206   31
# 6.0      A0101   45
#          A0201   56
#          A0202   40
#          A0203   34
#          A0204    9
# ...
