# %%
import pandas as pd
from sqlalchemy import create_engine
from haversine import haversine

# %%
engine = create_engine("mysql://admin:1234@localhost:3306/Tourlist")
tour_data = pd.read_sql("SELECT * FROM TOURLIST_SITE", engine)
scale_data = pd.read_sql("SELECT * FROM ANALYSIS_RESULT", engine)

# %%
lat = 32
lng = 128

cur_location = (lat,lng)

scale_data["dist"] = tour_data.apply(lambda x: haversine(cur_location, (x['mapy'], x['mapx'])), axis=1)

# %%
filter_tour1 = tour_data.loc[(tour_data["cat1"] == 'A03') | (tour_data["cat1"] == 'A04') | (tour_data["cat1"] == 'A05')]

filter_tour2 = scale_data.loc[(tour_data['cat1'] == 'A03') | (tour_data['cat1'] == 'A04') | (tour_data['cat1'] == 'A05')]

# %%
filter_tour2
# Out:
#        tour_id  readcount_score  congestion_score  star_avg  \
# 2            3          0.41050          0.347225     2.100
# 4            5          0.16603          0.545750     0.958
# 5            6          0.34720          0.549225     2.000
# 7            8          0.18656          0.721025     0.000
# 11          12          0.18782          0.676825     4.000
# ...        ...              ...               ...       ...
# 21475    21476          0.02784          0.425635     0.000
# 21478    21479          0.03092          0.425635     5.000
# 21479    21480          0.25829          0.425635     0.000
# 21481    21482          0.16458          0.425635     4.000
# 21483    21484          0.16111          0.425635     0.000
#
#                                               senti_word  senti_count  \
# 2                                 [['최고', 2], ['욕', -2]]            2
# 4      [['고급', 2], ['최고', 2], ['정', 1], ['일진', -1], [...            9
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

filter_tour[["dist_score"]] = scaler.fit_transform(filter_tour[["dist"]])
# Out:
# /home/jeenskki/.local/lib/python3.8/site-packages/pandas/core/indexing.py:659: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[k] = np.nan
# <ipython-input-13-dc52222f20db>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_tour[["dist_score"]] = scaler.fit_transform(filter_tour[["dist"]])
# /home/jeenskki/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dist = 100

filter_dist = filter_tour.loc[filter_cat["dist"] < int(dist, base=10)] if dist.isdigit() else filter_tour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-734975a6fa8c> in <module>
#       1 dist = 100
#       2
# ----> 3 filter_dist = filter_tour.loc[filter_cat["dist"] < int(dist, base=10)] if dist.isdigit() else filter_tour
#
# AttributeError: 'int' object has no attribute 'isdigit'

# %%
filter_tour
# Out:
#        tour_id  readcount_score  congestion_score  star_avg  \
# 2            3          0.41050          0.347225     2.100
# 4            5          0.16603          0.545750     0.958
# 5            6          0.34720          0.549225     2.000
# 7            8          0.18656          0.721025     0.000
# 11          12          0.18782          0.676825     4.000
# ...        ...              ...               ...       ...
# 21475    21476          0.02784          0.425635     0.000
# 21478    21479          0.03092          0.425635     5.000
# 21479    21480          0.25829          0.425635     0.000
# 21481    21482          0.16458          0.425635     4.000
# 21483    21484          0.16111          0.425635     0.000
#
#                                               senti_word  senti_count  \
# 2                                 [['최고', 2], ['욕', -2]]            2
# 4      [['고급', 2], ['최고', 2], ['정', 1], ['일진', -1], [...            9
# ...
