# %%
import pandas as pd

df = pd.read_csv('./tour_data.csv')

df.head(10).T
# Out:
#                                                                0  \
# Unnamed: 0                                                     1
# title                                                      ㈜코스테이
# cat1                                                         B02
# cat2                                                       B0201
# cat3                                                   B02010900
# areacode                                                       1
# addr1                                         서울특별시 강서구 곰달래로 247
# tel                                                 02-2643-8800
# mapx                                                     126.861
# mapy                                                     37.5322
# firstimage     http://tong.visitkorea.or.kr/cms/resource/22/1...
# firstimage2    http://tong.visitkorea.or.kr/cms/resource/22/1...
# contentid                                                1747824
# ...
