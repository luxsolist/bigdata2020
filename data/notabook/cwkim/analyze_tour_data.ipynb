# %%
import pandas as pd

df = pd.read_csv('../../tour_data.csv')
df.head(10).T
# Out:
#                                                                0  \
# Unnamed: 0                                                     1
# title                                                      ㈜코스테이
# cat1                                                         B02
# cat2                                                       B0201
# cat3                                                   B02010900
# areacode                                                       1
# addr1                                         서울특별시 강서구 곰달래로 247
# tel                                                 02-2643-8800
# mapx                                                     126.861
# mapy                                                     37.5322
# firstimage     http://tong.visitkorea.or.kr/cms/resource/22/1...
# firstimage2    http://tong.visitkorea.or.kr/cms/resource/22/1...
# contentid                                                1747824
# ...

# %%
df['areacode'].value_counts()
# Out:
# 32.0    2585
# 1.0     2548
# 36.0    2360
# 31.0    2277
# 38.0    1929
# 35.0    1912
# 37.0    1821
# 34.0    1196
# 33.0     969
# 39.0     862
# 6.0      702
# 2.0      655
# 7.0      544
# 4.0      440
# 3.0      366
# 5.0      324
# 8.0       49
# Name: areacode, dtype: int64

# %% [markdown]
# # areaCode
#
# 1:서울 / 2:인천 / 3:대전 / 4:대구 / 5:광주 / 6:부산 / 7:울산 / 8:세종특별자치시
#
# 31:경기도 / 32:강원도 / 33:충청북도 / 34:충청남도 / 35:경상북도 / 36:경상남도 / 37:전라북도 / 38:전라남도 / 39:제주도

# %%
df['areacode'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![content_typeid.png](attachment:content_typeid.png)

# %%
df['contenttypeid'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_read = df.sort_values(by=['readcount'], ascending=False)
df_read.head(300).T
# Out:
#                                                            7312   \
# Unnamed: 0                                                  2127
# title                                                        제부도
# cat1                                                         A01
# cat2                                                       A0101
# cat3                                                   A01011300
# areacode                                                      31
# addr1                                        경기도 화성시 서신면 제부말길 96
# tel                                                          NaN
# mapx                                                     126.624
# mapy                                                     37.1687
# firstimage     http://tong.visitkorea.or.kr/cms/resource/34/2...
# firstimage2    http://tong.visitkorea.or.kr/cms/resource/34/2...
# contentid                                                 125503
# ...

# %%
df2 = df.dropna()
